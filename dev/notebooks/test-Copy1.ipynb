# %%
from ultralytics import YOLO

# %%
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  7.66it/s]
#                    all         40         42      0.945      0.824      0.922      0.544

#  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  5.86it/s]
#                    all         40         42      0.973      0.873      0.953       0.57

# %%
model = YOLO('/home/jayant/project/CV/Eff-Yolo8/dev/cfg/yolov8test.yaml')
# model = YOLO('yolov8n.yaml')

# %%
model.train(data="/home/jayant/project/CV/Eff-Yolo8/datasets/racoon/data.yaml",epochs=300,device=0, batch=32, project="Yolov8_racoon_test", name="racoon3_8p_mod")
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5842MiB)
# ...

# %%
model.train(data="/home/jayant/project/CV/Eff-Yolo8/datasets/racoon/data.yaml",epochs=300,device=0, batch=-1, project="Yolov8_racoon_test", name="racoon1_p_added",exist_ok=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5842MiB)
# ...

# %%
model.train(data="/home/jayant/project/CV/Eff-Yolo8/datasets/racoon/data.yaml",epochs=300,device=0, batch=-1, close_mosaic=50, project="Yolov8_racoon_test", name="racoon0_8p_added",exist_ok=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5842MiB)
# ...
